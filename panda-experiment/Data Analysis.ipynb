# %%
import os
dir(os)
# Out:
# ['DirEntry',
#  'F_OK',
#  'MutableMapping',
#  'O_APPEND',
#  'O_BINARY',
#  'O_CREAT',
#  'O_EXCL',
#  'O_NOINHERIT',
#  'O_RANDOM',
#  'O_RDONLY',
#  'O_RDWR',
#  'O_SEQUENTIAL',
#  'O_SHORT_LIVED',
#  'O_TEMPORARY',
#  'O_TEXT',
#  'O_TRUNC',
#  'O_WRONLY',
#  'P_DETACH',
#  'P_NOWAIT',
#  'P_NOWAITO',
#  'P_OVERLAY',
#  'P_WAIT',
#  'PathLike',
#  'R_OK',
#  'SEEK_CUR',
#  'SEEK_END',
#  'SEEK_SET',
#  'TMP_MAX',
#  'W_OK',
#  'X_OK',
#  '_Environ',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_execvpe',
#  '_exists',
#  '_exit',
#  '_fspath',
#  '_get_exports_list',
#  '_putenv',
#  '_unsetenv',
#  '_wrap_close',
#  'abc',
#  'abort',
#  'access',
#  'altsep',
#  'chdir',
#  'chmod',
#  'close',
#  'closerange',
#  'cpu_count',
#  'curdir',
#  'defpath',
#  'device_encoding',
#  'devnull',
#  'dup',
#  'dup2',
#  'environ',
#  'error',
#  'execl',
#  'execle',
#  'execlp',
# ...

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx',
#  'supermarkets_commas.txt',
#  'supermarkets_semicolan.txt',
#  'Testing.ipynb',
#  'Untitled.ipynb']

# %%
import pandas
df = pandas.read_csv("supermarkets.csv")
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
dir(df)
# Out:
# ['Address',
#  'City',
#  'Country',
#  'Employees',
#  'ID',
#  'Name',
#  'State',
#  'T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
# ...

# %%
df.set_index("ID")
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df_json = pandas.read_json("supermarkets.json")
df_json.set_index("ID")
# Out:
#             Address           City Country  Employees         Name  \
# ID
# 1      3666 21st St  San Francisco     USA          8      Madeira
# 2    735 Dolores St  San Francisco     USA         15  Bready Shop
# 3       332 Hill St  San Francisco     USA         25  Super River
# 4      3995 23rd St  San Francisco     USA         10   Ben's Shop
# 5   1056 Sanchez St  San Francisco     USA         12      Sanchez
# 6   551 Alvarado St  San Francisco     USA         20   Richvalley
#
#                State
# ID
# 1           CA 94114
# 2           CA 94119
# 3   California 94114
# 4           CA 94114
# 5         California
# 6           CA 94114

# %%
df_xlsx = pandas.read_excel("supermarkets.xlsx")
df_xlsx.set_index("ID")
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df_txt = pandas.read_csv("supermarkets_commas.txt")
df_txt.set_index("ID")
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df_semi = pandas.read_csv("supermarkets_semicolan.txt", sep=";")
df_semi.set_index("ID")
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df_api_csv = pandas.read_csv("http://pythonhow.com/supermarkets.csv")
df_api_csv.set_index("ID")
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df_api_json = pandas.read_json("http://pythonhow.com/supermarkets.json")
df_api_json.set_index("ID")
# Out:
#             Address           City Country  Employees         Name  \
# ID
# 1      3666 21st St  San Francisco     USA          8      Madeira
# 2    735 Dolores St  San Francisco     USA         15  Bready Shop
# 3       332 Hill St  San Francisco     USA         25  Super River
# 4      3995 23rd St  San Francisco     USA         10   Ben's Shop
# 5   1056 Sanchez St  San Francisco     USA         12      Sanchez
# 6   551 Alvarado St  San Francisco     USA         20   Richvalley
#
#                State
# ID
# 1           CA 94114
# 2           CA 94119
# 3   California 94114
# 4           CA 94114
# 5         California
# 6           CA 94114

# %%
print("Data Modification")
# Out:
# Data Modification

# %%
df_dm = pandas.read_json("http://pythonhow.com/supermarkets.json")
df_dm = df_dm.set_index("Address")
df_dm
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop
# 332 Hill St      San Francisco     USA         25   3  Super River
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#                             State
# Address
# 3666 21st St             CA 94114
# 735 Dolores St           CA 94119
# 332 Hill St      California 94114
# 3995 23rd St             CA 94114
# 1056 Sanchez St        California
# 551 Alvarado St          CA 94114

# %%
df_dm.loc["3666 21st St":"3995 23rd St", "City":"ID"]
# Out:
#                          City Country  Employees  ID
# Address
# 3666 21st St    San Francisco     USA          8   1
# 735 Dolores St  San Francisco     USA         15   2
# 332 Hill St     San Francisco     USA         25   3
# 3995 23rd St    San Francisco     USA         10   4

# %%
df_dm.iloc[1:3, 1:3]
# Out:
#                Country  Employees
# Address
# 735 Dolores St     USA         15
# 332 Hill St        USA         25

# %%
list(df_dm.iloc[:, 0])
# Out:
# ['San Francisco',
#  'San Francisco',
#  'San Francisco',
#  'San Francisco',
#  'San Francisco',
#  'San Francisco']

# %%
list(df_dm.loc[:, "ID"])
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
df_dm.ix[1, 0]
# Out:
# C:\Users\PRINCE\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# 'San Francisco'

# %%
df_dm.drop("332 Hill St", 0)
# Out:
#                           City Country  Employees  ID         Name       State
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira    CA 94114
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop    CA 94119
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop    CA 94114
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez  California
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley    CA 94114

# %%
df_dm.drop(df_dm.columns[0:3], 1)
# Out:
#                  ID         Name             State
# Address
# 3666 21st St      1      Madeira          CA 94114
# 735 Dolores St    2  Bready Shop          CA 94119
# 332 Hill St       3  Super River  California 94114
# 3995 23rd St      4   Ben's Shop          CA 94114
# 1056 Sanchez St   5      Sanchez        California
# 551 Alvarado St   6   Richvalley          CA 94114

# %%
df_dm
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop
# 332 Hill St      San Francisco     USA         25   3  Super River
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#                             State
# Address
# 3666 21st St             CA 94114
# 735 Dolores St           CA 94119
# 332 Hill St      California 94114
# 3995 23rd St             CA 94114
# 1056 Sanchez St        California
# 551 Alvarado St          CA 94114

# %%
df_dm.shape
# Out:
# (6, 6)

# %%
df_dm.index
# Out:
# Index(['3666 21st St', '735 Dolores St', '332 Hill St', '3995 23rd St',
#        '1056 Sanchez St', '551 Alvarado St'],
#       dtype='object', name='Address')

# %%
len(df_dm.index)
# Out:
# 6

# %%
df_dm["Continent"] = df_dm.shape[0] * ["North America"]
df_dm
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop
# 332 Hill St      San Francisco     USA         25   3  Super River
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#                      Continent
# Address
# 3666 21st St     North America
# 735 Dolores St   North America
# 332 Hill St      North America
# 3995 23rd St     North America
# 1056 Sanchez St  North America
# 551 Alvarado St  North America

# %%
df_dm["Continent"] = df_dm["Country"] + ", " + "North America"
df_dm
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop
# 332 Hill St      San Francisco     USA         25   3  Super River
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#                           Continent
# Address
# 3666 21st St     USA, North America
# 735 Dolores St   USA, North America
# 332 Hill St      USA, North America
# 3995 23rd St     USA, North America
# 1056 Sanchez St  USA, North America
# 551 Alvarado St  USA, North America

# %%
df_dm_t = df_dm.T
df_dm_t
# Out:
# Address          3666 21st St      735 Dolores St         332 Hill St  \
# City            San Francisco       San Francisco       San Francisco
# Country                   USA                 USA                 USA
# Employees                   8                  15                  25
# ID                          1                   2                   3
# Name                  Madeira         Bready Shop         Super River
# Continent  USA, North America  USA, North America  USA, North America
#
# Address          3995 23rd St     1056 Sanchez St     551 Alvarado St
# City            San Francisco       San Francisco       San Francisco
# Country                   USA                 USA                 USA
# Employees                  10                  12                  20
# ID                          4                   5                   6
# Name               Ben's Shop             Sanchez          Richvalley
# ...

# %%
df_dm_t["My Address"] = ["My City", "My Country", 30, 7, "My Shop", "My Continent"]
df_dm_t
# Out:
# Address          3666 21st St      735 Dolores St         332 Hill St  \
# City            San Francisco       San Francisco       San Francisco
# Country                   USA                 USA                 USA
# Employees                   8                  15                  25
# ID                          1                   2                   3
# Name                  Madeira         Bready Shop         Super River
# Continent  USA, North America  USA, North America  USA, North America
#
# Address          3995 23rd St     1056 Sanchez St     551 Alvarado St  \
# City            San Francisco       San Francisco       San Francisco
# Country                   USA                 USA                 USA
# Employees                  10                  12                  20
# ID                          4                   5                   6
# Name               Ben's Shop             Sanchez          Richvalley
# ...

# %%
df_dm = df_dm_t.T
df_dm
# Out:
#                           City     Country Employees ID         Name  \
# Address
# 3666 21st St     San Francisco         USA         8  1      Madeira
# 735 Dolores St   San Francisco         USA        15  2  Bready Shop
# 332 Hill St      San Francisco         USA        25  3  Super River
# 3995 23rd St     San Francisco         USA        10  4   Ben's Shop
# 1056 Sanchez St  San Francisco         USA        12  5      Sanchez
# 551 Alvarado St  San Francisco         USA        20  6   Richvalley
# My Address             My City  My Country        30  7      My Shop
#
#                           Continent
# Address
# 3666 21st St     USA, North America
# 735 Dolores St   USA, North America
# 332 Hill St      USA, North America
# 3995 23rd St     USA, North America
# 1056 Sanchez St  USA, North America
# 551 Alvarado St  USA, North America
# My Address             My Continent

# %%
df_x = pandas.read_json("http://pythonhow.com/supermarkets.json")
df_x = df_x.set_index("Address")
df_x
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop
# 332 Hill St      San Francisco     USA         25   3  Super River
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#                             State
# Address
# 3666 21st St             CA 94114
# 735 Dolores St           CA 94119
# 332 Hill St      California 94114
# 3995 23rd St             CA 94114
# 1056 Sanchez St        California
# 551 Alvarado St          CA 94114

# %%
df_y = pandas.read_json("http://pythonhow.com/supermarkets.json")
df_y["Continent"] = df_y["Country"] + ", " + "North America"
df_y
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State           Continent
# 0          CA 94114  USA, North America
# 1          CA 94119  USA, North America
# 2  California 94114  USA, North America
# 3          CA 94114  USA, North America
# 4        California  USA, North America
# 5          CA 94114  USA, North America

# %%
df_xy = pandas.merge(left=df_x, right=df_y, on="ID")
df_xy
# Out:
#           City_x Country_x  Employees_x  ID       Name_x           State_x  \
# 0  San Francisco       USA            8   1      Madeira          CA 94114
# 1  San Francisco       USA           15   2  Bready Shop          CA 94119
# 2  San Francisco       USA           25   3  Super River  California 94114
# 3  San Francisco       USA           10   4   Ben's Shop          CA 94114
# 4  San Francisco       USA           12   5      Sanchez        California
# 5  San Francisco       USA           20   6   Richvalley          CA 94114
#
#            Address         City_y Country_y  Employees_y       Name_y  \
# 0     3666 21st St  San Francisco       USA            8      Madeira
# 1   735 Dolores St  San Francisco       USA           15  Bready Shop
# 2      332 Hill St  San Francisco       USA           25  Super River
# 3     3995 23rd St  San Francisco       USA           10   Ben's Shop
# 4  1056 Sanchez St  San Francisco       USA           12      Sanchez
# ...

# %%
import geopy
dir(geopy)
# Out:
# ['ArcGIS',
#  'AzureMaps',
#  'BANFrance',
#  'Baidu',
#  'Bing',
#  'DataBC',
#  'GeoNames',
#  'GeocodeEarth',
#  'GeocodeFarm',
#  'Geolake',
#  'GoogleV3',
#  'Here',
#  'IGNFrance',
#  'LiveAddress',
#  'Location',
#  'MapBox',
#  'Nominatim',
#  'OpenCage',
#  'OpenMapQuest',
#  'Pelias',
#  'Photon',
#  'PickPoint',
#  'Point',
#  'Timezone',
#  'TomTom',
#  'What3Words',
#  'Yandex',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'compat',
#  'exc',
#  'format',
#  'geocoders',
#  'get_geocoder_for_service',
#  'location',
#  'point',
#  'timezone',
#  'units',
#  'util']

# %%
dir(geopy.geocoders)
# Out:
# ['ArcGIS',
#  'AzureMaps',
#  'BANFrance',
#  'Baidu',
#  'Bing',
#  'DataBC',
#  'GeoNames',
#  'GeocodeEarth',
#  'GeocodeFarm',
#  'GeocoderNotFound',
#  'Geolake',
#  'GoogleV3',
#  'Here',
#  'IGNFrance',
#  'LiveAddress',
#  'MapBox',
#  'Nominatim',
#  'OpenCage',
#  'OpenMapQuest',
#  'Pelias',
#  'Photon',
#  'PickPoint',
#  'SERVICE_TO_GEOCODER',
#  'TomTom',
#  'What3Words',
#  'Yandex',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'arcgis',
#  'azure',
#  'baidu',
#  'banfrance',
#  'base',
#  'bing',
#  'databc',
#  'geocodeearth',
#  'geocodefarm',
#  'geolake',
#  'geonames',
#  'get_geocoder_for_service',
#  'googlev3',
#  'here',
#  'ignfrance',
#  'mapbox',
#  'opencage',
#  'openmapquest',
#  'options',
#  'osm',
#  'pelias',
#  'photon',
#  'pickpoint',
#  'smartystreets',
#  'tomtom',
#  'what3words',
#  'yandex']

# %%
from geopy.geocoders import Nominatim
nom = Nominatim(user_agent="Data Analysis")
nom.geocode("3666 21st St, San Francisco, CA 94114")
# Out:
# Location(3666, 21st Street, Noe Valley, SF, California, 94114, USA, (37.756488877551, -122.429343346939, 0.0))

# %%
location = nom.geocode("3666 21st St, San Francisco, CA 94114")
print((location.latitude, location.longitude))
# Out:
# (37.756488877551, -122.429343346939)

# %%
df_new = pandas.read_csv("supermarkets.csv")
df_new
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df_new["Address"] = df_new["Address"] + ", " + df_new["City"] + "," + df_new["State"] + ", " + df_new["Country"]
df_new
# Out:
#    ID                                            Address           City  \
# 0   1  3666 21st St, San Francisco,CA 94114, USA, San...  San Francisco
# 1   2  735 Dolores St, San Francisco,CA 94119, USA, S...  San Francisco
# 2   3  332 Hill St, San Francisco,California 94114, U...  San Francisco
# 3   4  3995 23rd St, San Francisco,CA 94114, USA, San...  San Francisco
# 4   5  1056 Sanchez St, San Francisco,California, USA...  San Francisco
# 5   6  551 Alvarado St, San Francisco,CA 94114, USA, ...  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                        Co-orndinates   Latitude   Longitude
# ...

# %%
df_new["Co-orndinates"] = df["Address"].apply(nom.geocode)
df_new
# Out:
#    ID                                            Address           City  \
# 0   1  3666 21st St, San Francisco,CA 94114, USA, San...  San Francisco
# 1   2  735 Dolores St, San Francisco,CA 94119, USA, S...  San Francisco
# 2   3  332 Hill St, San Francisco,California 94114, U...  San Francisco
# 3   4  3995 23rd St, San Francisco,CA 94114, USA, San...  San Francisco
# 4   5  1056 Sanchez St, San Francisco,California, USA...  San Francisco
# 5   6  551 Alvarado St, San Francisco,CA 94114, USA, ...  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                        Co-orndinates
# ...

# %%
df_new["Co-orndinates"][0].latitude
# Out:
# 39.968982

# %%
df_new["Latitude"] = df_new["Co-orndinates"].apply(lambda x: x.latitude if x != None else None)
df_new["Longitude"] = df_new["Co-orndinates"].apply(lambda x: x.longitude if x != None else None)
df_new
# Out:
#    ID                                            Address           City  \
# 0   1  3666 21st St, San Francisco,CA 94114, USA, San...  San Francisco
# 1   2  735 Dolores St, San Francisco,CA 94119, USA, S...  San Francisco
# 2   3  332 Hill St, San Francisco,California 94114, U...  San Francisco
# 3   4  3995 23rd St, San Francisco,CA 94114, USA, San...  San Francisco
# 4   5  1056 Sanchez St, San Francisco,California, USA...  San Francisco
# 5   6  551 Alvarado St, San Francisco,CA 94114, USA, ...  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                        Co-orndinates   Latitude   Longitude
# ...

# %%
df_new["Address"][0]
# Out:
# '3666 21st St, San Francisco,CA 94114, USA, San Francisco,CA 94114, USA, San Francisco,CA 94114, USA'
